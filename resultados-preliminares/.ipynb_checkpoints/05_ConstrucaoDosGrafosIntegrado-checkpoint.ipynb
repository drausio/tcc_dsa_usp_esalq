# %% [markdown]
# # Trabalho de Conclusão de Curso - TCC
# ### Turma - DSA T212
# ### Aluno : Drausio Gomes dos Santos
# ### Orientadora: Gabrielle Maria Romeiro Lombardi
# ### Tema: Construção e uso de modelos de grafos para representação e análise da estrutura organizacional da administração pública federal.
# ## Resultados Preliminares

# %% [markdown]
# ### Etapa 4: Construção dos Grafos
# <p> Construção das representações de estruturas organizacionais em grafos.</p>

# %% [markdown]
# #### Importando as bibliotecas

# %%
# !pip install igraph
# !pip install pycairo
# !pip install cairocffi
# !pip install python-igraph
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: igraph in c:\programdata\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: texttable>=1.6.2 in c:\programdata\anaconda3\lib\site-packages (from igraph) (1.6.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pycairo in c:\programdata\anaconda3\lib\site-packages (1.21.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cairocffi in c:\programdata\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: cffi>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from cairocffi) (1.15.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.1.0->cairocffi) (2.21)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-igraph in c:\programdata\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: igraph==0.10.1 in c:\programdata\anaconda3\lib\site-packages (from python-igraph) (0.10.1)
# Requirement already satisfied: texttable>=1.6.2 in c:\programdata\anaconda3\lib\site-packages (from igraph==0.10.1->python-igraph) (1.6.4)

# %%
import time
import datetime as dt
from datetime import datetime
import pickle
import igraph as ig
from igraph import *
print("igraph : ",ig.__version__)
import pandas as pd
import pytz

class Main:     
    def show_current_time(self):
        ini = time.time()
        tz_SP = pytz.timezone('America/Sao_Paulo') 
        now = datetime.now(tz_SP)
        current_time = now.strftime("%d/%m/%Y %H:%M:%S")
        print("Current Time =", current_time)  

main = Main()
# Out:
# igraph :  0.10.1

# %% [markdown]
# #### Criando data frames para cada ano

# %%
anos = [2019,2020,2021,2022]
base_path = "C:/projetos/tcc_dsa_usp_esalq/"
dfs = []
for ano in anos:
    anoRef = str(ano)
    data_frame_orig = pd.read_csv(base_path + "dados/dou/" + anoRef + "/" + anoRef +".csv")    
    dfs.append(data_frame_orig)

df = pd.concat(dfs, ignore_index=True)
df["entidades"] = df["emissor"].str.split("/")
df["unidade_emissora"] = df["entidades"].apply(lambda x:x[len(x)-1])
df.insert(2,"unidade_superior", df["entidades"].apply(lambda x:x[0]))
df['tipo'] = df['tipo'].astype('category')
df['se_ato_assinado'] = df['responsavel'].notnull()
df['se_possui_cargo'] = df['cargo'].notnull()

# %% [markdown]
# ### Análise do Dados

# %%
print("Checagem da consistência de ID único")
print(len(df["id"]))
print(len(df["id"].unique()))
print("-------------------------------------")
print(df["tipo"].unique())
print(df.sample(100000).info())
print(df.sample(100000).describe(datetime_is_numeric=True))
# Out:
# Checagem da consistência de ID único
# 3233684
# 3233684
# -------------------------------------
# ['Decreto numerado', 'Lei', 'Alvará', 'Portaria', 'Despacho', ..., 'Extrato de Reconhecimento', 'Extrato de Carta-contrato', 'Extrato de Termo de Ajustamento de Conduta', 'Extrato de Dispensa de Chamamento Público', 'Aviso de Tomada de Subsídios']
# Length: 235
# Categories (235, object): ['Acordo Coletivo de Trabalho', 'Acórdão', 'Agenda Regulatória', 'Ajuste', ..., 'Súmula Administrativa', 'Termo de Autorização', 'Termo de Liberação de Operação', 'autorização de acesso']
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 1631716 to 2466165
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                100000 non-null  object
#  1   tipo              100000 non-null  category
#  2   unidade_superior  100000 non-null  object
#  3   emissor           100000 non-null  object
#  4   data              100000 non-null  object
#  5   responsavel       61631 non-null   object
#  6   cargo             36119 non-null   object
#  7   entidades         100000 non-null  object
#  8   unidade_emissora  100000 non-null  object
#  9   se_ato_assinado   100000 non-null  bool
#  10  se_possui_cargo   100000 non-null  bool
# dtypes: bool(2), category(1), object(8)
# memory usage: 7.3+ MB
# None
#                                      id      tipo unidade_superior  \
# count                            100000    100000           100000
# unique                           100000       191               48
# top     S03042020/530_20200408_12559497  Portaria      Prefeituras
# freq                                  1     17733            27848
#
#                                          emissor        data  \
# count                                     100000      100000
# unique                                     12869         927
# top     Ministério da Saúde/Gabinete do Ministro  01/07/2022
# freq                                         746         206
#
#                   responsavel      cargo  \
# count                   61733      36146
# unique                  24603       5002
# top     Comissão de Licitação  Pregoeiro
# freq                      528       5752
#
#                                           entidades      unidade_emissora  \
# count                                        100000                100000
# unique                                        12869                 10643
# top     [Ministério da Saúde, Gabinete do Ministro]  Gabinete do Ministro
# freq                                            746                  2124
#
#        se_ato_assinado se_possui_cargo
# count           100000          100000
# unique               2               2
# top               True           False
# freq             61733           63854

# %%
df
# Out:
#                                           id                      tipo  \
# 0        S01012019/1020_20190112_991201162-2          Decreto numerado
# 1           S01012019/1020_20190116_11391945                       Lei
# 2            S01012019/515_20190102_11303736                    Alvará
# 3            S01012019/515_20190102_11303780                    Alvará
# 4            S01012019/515_20190102_11303801                  Portaria
# ...                                      ...                       ...
# 3233679      S03112022/609_20221130_20116254        Aviso de Suspensão
# 3233680      S03112022/609_20221130_20116255   Resultado de Julgamento
# 3233681      S03112022/609_20221130_20116333  Extrato de Termo Aditivo
# 3233682      S03112022/609_20221130_20116336       Extrato de Contrato
# 3233683      S03112022/609_20221130_20116342  Extrato de Termo Aditivo
#
#                                           unidade_superior  \
# 0                                 Atos do Poder Judiciário
# 1                                Atos do Poder Legislativo
# 2                          Ministério da Segurança Pública
# 3                          Ministério da Segurança Pública
# 4        Ministério da Ciência, Tecnologia, Inovações e...
# ...                                                    ...
# 3233679                               Ministério da Defesa
# 3233680                             Ministério da Economia
# 3233681                        Ministério das Comunicações
# 3233682                        Ministério das Comunicações
# 3233683                                Ministério da Saúde
#
#                                                    emissor        data  \
# 0                                 Atos do Poder Judiciário  12/01/2019
# 1                                Atos do Poder Legislativo  16/01/2019
# 2        Ministério da Segurança Pública/Departamento d...  02/01/2019
# 3        Ministério da Segurança Pública/Departamento d...  02/01/2019
# 4        Ministério da Ciência, Tecnologia, Inovações e...  02/01/2019
# ...                                                    ...         ...
# 3233679  Ministério da Defesa/Comando da Marinha/Empres...  30/11/2022
# 3233680  Ministério da Economia/Empresa de Tecnologia e...  30/11/2022
# 3233681  Ministério das Comunicações/Empresa Brasileira...  30/11/2022
# 3233682  Ministério das Comunicações/Empresa Brasileira...  30/11/2022
# 3233683  Ministério da Saúde/Fundação Oswaldo Cruz/Dire...  30/11/2022
#
#                               responsavel      cargo  \
# 0                                     NaN        NaN
# 1                  JAIR MESSIAS BOLSONARO        NaN
# 2         ROSILENE GLEICE DUARTE SANTIAGO        NaN
# 3         ROSILENE GLEICE DUARTE SANTIAGO        NaN
# 4         VILMA DE FÁTIMA ALVARENGA FANIS        NaN
# ...                                   ...        ...
# 3233679       NAIR CARLA FROMENT TEIXEIRA  Pregoeira
# 3233680  MARIO HENRIQUE BERNARDO DA SILVA  Pregoeiro
# 3233681                               NaN        NaN
# 3233682                               NaN        NaN
# 3233683                               NaN        NaN
#
#                                                  entidades  \
# 0                               [Atos do Poder Judiciário]
# 1                              [Atos do Poder Legislativo]
# 2        [Ministério da Segurança Pública, Departamento...
# 3        [Ministério da Segurança Pública, Departamento...
# 4        [Ministério da Ciência, Tecnologia, Inovações ...
# ...                                                    ...
# 3233679  [Ministério da Defesa, Comando da Marinha, Emp...
# 3233680  [Ministério da Economia, Empresa de Tecnologia...
# 3233681  [Ministério das Comunicações, Empresa Brasilei...
# 3233682  [Ministério das Comunicações, Empresa Brasilei...
# 3233683  [Ministério da Saúde, Fundação Oswaldo Cruz, D...
#
#                                           unidade_emissora  se_ato_assinado  \
# 0                                 Atos do Poder Judiciário            False
# 1                                Atos do Poder Legislativo             True
# 2        Coordenação-Geral de Controle de Serviços e Pr...             True
# 3        Coordenação-Geral de Controle de Serviços e Pr...             True
# 4            Coordenação-Geral de Radiodifusão Comunitária             True
# ...                                                    ...              ...
# 3233679               Empresa Gerencial de Projetos Navais             True
# 3233680  Empresa de Tecnologia e Informações da Previdê...             True
# 3233681                   Superintendência Estadual N3 BSB            False
# 3233682                    Superintendência Estadual N1 MG            False
# 3233683                 Coordenação-Geral de Administração            False
#
#          se_possui_cargo
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
# ...                  ...
# 3233679             True
# 3233680             True
# 3233681            False
# 3233682            False
# 3233683            False
#
# [3233684 rows x 11 columns]

# %% [markdown]
# #### Montando os grafo integrado utilizando IGraph

# %%
print("Início da criação dos grafo integrado.")    
main.show_current_time()
print("------------------------------------") 
amostra = 100
g = ig.Graph(directed=True)
g["name"]="Unidades Organizacionais da Administração Pública - Grafo Integrado "
df_sample = df.sample(amostra)
print("tamanho amostra: ", len(df_sample))
for index, row in df_sample.iterrows(): 
    for index,ent in enumerate(row["entidades"]): 
        split_data = row["data"].split("/")
        dia = split_data[0]
        mes = split_data[1]
        ano = split_data[2]
        d = dt.date(int(ano),int(mes),int(dia))
        try:
            vert = g.vs.find(ent)
            vert["weight"] = vert["weight"] +  1
            if ( d < vert["data_inicio"] ):
                vert["data_inicio"] = d                    
            if ( d > vert["data_termino"] ):
                vert["data_termino"] = d
            vert["tempo_medio"] = (vert["data_termino"] - vert["data_inicio"]) / vert["weight"]
        except:
            g.add_vertices([ent])
            vert = g.vs.find(ent)            
            vert["data_inicio"]  = d
            vert["data_termino"] = d
            vert["label"] = ent
            vert["weight"] =  1
            vert["tempo_medio"]=0.0            
                
    for index,ent in enumerate(row["entidades"]): 
        split_data = row["data"].split("/")
        dia = split_data[0]
        mes = split_data[1]
        ano = split_data[2]
        d = dt.date(int(ano),int(mes),int(dia))
        if row["se_ato_assinado"] == True:
            id = str(row["responsavel"])+"-->"+str(row["cargo"])
            try:
                vert_r = g.vs.find(id) 
                vert_r["weight"] = vert_r["weight"] +  1
                if ( d < vert_r["data_inicio"] ):
                    vert_r["data_inicio"] = d                    
                if ( d > vert_r["data_termino"] ):
                    vert_r["data_termino"] = d
                vert_r["tempo_medio"] = (vert_r["data_termino"] - vert_r["data_inicio"]) / vert_r["weight"]
                
                eg_r = g.es.select(lambda edge: edge.source_vertex["name"]  == row["unidade_emissora"] and \
                    edge.target_vertex["name"] == id ) 
                if len(eg_r) == 0:  
                    g.add_edges([(row["unidade_emissora"] , id)])
                    eg_r[0]["label"]=d
                else:                    
                    eg_r[0]["weight"] = eg_r[0]["weight"] +  1
                    if ( d < eg_r[0]["data_inicio"] ):
                        eg_r[0]["data_inicio"] = d                    
                    if ( d > eg_r[0]["data_termino"] ):
                        eg_r[0]["data_termino"] = d
                    eg_r[0]["tempo_medio"] = (eg_r[0]["data_termino"] - eg_r[0]["data_inicio"]) / eg_r[0]["weight"]
                    eg_r[0]["label"]=str(eg_r[0]["data_inicio"])+"-->"+str(eg_r[0]["data_termino"])
            except:
                
                try:
                    g.add_vertices([id])
                    vert_r = g.vs.find(id)
                    vert_r["label"]=id
                    vert_r["weight"] = 1
                    vert_r["data_inicio"] = d
                    vert_r["data_termino"] = d
                    g.add_edges([(row["unidade_emissora"] , id)])
                    eg_r = g.es.select(lambda edge: edge.source_vertex["name"]  == row["unidade_emissora"] and \
                        edge.target_vertex["name"] == id ) 
                    eg_r[0]["data_inicio"] =  d
                    eg_r[0]["data_termino"] =  d
                    eg_r[0]["weight"] =  1
                    eg_r[0]["tempo_medio"]=0.0
                    eg_r[0]["label"]=d
                except:
                    print("não achou")
        
    for index,ent in enumerate(row["entidades"]): 
        if len(row['entidades']) > index+1:
            eg = g.es.select(lambda edge: edge.source_vertex["name"]  == ent and \
                            edge.target_vertex["name"] == row['entidades'][index+1] ) 
            split_data = row["data"].split("/")
            dia = split_data[0]
            mes = split_data[1]
            ano = split_data[2]
            d = dt.date(int(ano),int(mes),int(dia))
            if len(eg) > 0:                
                eg[0]["weight"] = eg[0]["weight"] +  1
                if ( d < eg[0]["data_inicio"] ):
                    eg[0]["data_inicio"] = d                    
                if ( d > eg[0]["data_termino"] ):
                    eg[0]["data_termino"] = d
                eg[0]["tempo_medio"] = (eg[0]["data_termino"] - eg[0]["data_inicio"]) / eg[0]["weight"]
                eg[0]["label"]=str(eg[0]["data_inicio"])+"-->"+str(eg[0]["data_termino"])
            else:
                g.add_edges([(ent , row['entidades'][index+1])])
                eg = g.es.select(lambda edge: edge.source_vertex["name"]  == ent and \
                        edge.target_vertex["name"] == row['entidades'][index+1] ) 
                eg[0]["data_inicio"] =  d
                eg[0]["data_termino"] =  d
                eg[0]["weight"] =  1
                eg[0]["tempo_medio"]=0.0
                eg[0]["label"]=d
                
with open("grafoIntegrado.pkl", 'wb') as pickle_file:
    pickle.dump(g, pickle_file)
    print("------------------------------------")                 
print("Término da criação dos grafos anuais.")    
main.show_current_time()
# Out:
# Início da criação dos grafo integrado.
# Current Time = 15/02/2023 19:31:15
# ------------------------------------
# tamanho amostra:  100
# ------------------------------------
# Término da criação dos grafos anuais.
# Current Time = 15/02/2023 19:31:15

# %% [markdown]
# #### Visualizando os grafos

# %%
def pesquisa_por_nome(ga,nome):
    g = ig.Graph(directed=True)
    edges_indices = []
    for ea in ga.es:
        #print(nome.lower())
        #print(ea.target_vertex["name"].lower())
        if nome.lower() in ea.target_vertex["name"].lower():
            print(ea.target_vertex["name"].lower())
        eg = ga.es.select(lambda edge: nome.lower() in edge.target_vertex["name"].lower() ) 
        if (len(eg) == 0):
            continue  
        else:
            for e in eg:
                edges_indices.append(e.index)
            
    print(edges_indices)        
          
    return ga.subgraph_edges(edges_indices)  
   
out_fig_name = "grafoIntegrado.eps"
grafo_integrado = pickle.load(open("grafoIntegrado.pkl", "rb"))
visual_style = {}
visual_style["bbox"] = (600,900)
visual_style["margin"] = 140
visual_style["vertex_color"] = 'green'
visual_style["vertex_frame_color"] = 'green'
visual_style["vertex_label_dist"] = 1.5
visual_style["edge_color"] = 'yellow'
visual_style["vertex_size"] = 20
visual_style["vertex_label_size"] = 12
visual_style["vertex_label_color"] = ['navy','maroon','black','blue','red',\
                                      'brown','fuchsia','teal','purple']
visual_style["edge_curved"] = True
#visual_style["layout"] = grafo2019.layout_reingold_tilford_circular()
print(grafo_integrado.summary())
nome = "Antonio"
grafo_filtrado = pesquisa_por_nome(grafo_integrado,nome)
grafo_filtrado
#plot(grafo_filtrado, out_fig_name, **visual_style)

# %%
print("Início da criação dos grafo integrado.")    
main.show_current_time()
print("------------------------------------") 
for ano in anos:
    #amostra = 50000
    g = ig.Graph(directed=True)
    contador_vertices = 0
    contador_arestas = 0
    g["name"]="Unidades Organizacionais da Administração Pública - " + str(ano)
    df_sample = listaAno[ano - 2019]["df"]
    #.sample(n=amostra)
    print("tamanho amostra: ", len(df_sample))
    for index, row in df_sample.iterrows(): 
        split_data = row["data"].split("/")
        dia = split_data[0]
        mes = split_data[1]
        ano = split_data[2]
        d = dt.date(int(ano),int(mes),int(dia))
        for index,ent in enumerate(row["entidades"]):        
            try:
                vert = g.vs.find(ent) 
                #vert["peso"] = vert["peso"] + 1
                #if ( d < vert["data_inicio"] ):
                #    vert["data_inicio"] = d
                #if ( d > vert["data_termino"] ):
                #    vert["data_termino"] = d
                #vert["tempo_medio"] = (vert["data_termino"] - vert["data_inicio"]) / vert["peso"]
            except:
                if  index < 2 :
                    g.add_vertices([ent])
                    vert = g.vs.find(ent)            
                    #vert["data_inicio"] =  d
                    #vert["data_termino"] =  d
                    vert["label"]=ent
                    #vert["peso"] =  1
                    #vert["tempo_medio"]=0.0
                    contador_vertices = contador_vertices + 1
    
        for (index,ent) in enumerate(row['entidades']):
            if len(row['entidades']) > index+1 and index < 1 :
                eg = g.es.select(lambda edge: edge.source_vertex["name"]  == ent and \
                            edge.target_vertex["name"] == row['entidades'][index+1] ) 
                #if len(eg) > 0:
                #eg[0]["peso"] = eg[0]["peso"] +  1
                #if ( d < eg[0]["data_inicio"] ):
                #    eg[0]["data_inicio"] = d                    
                #if ( d > eg[0]["data_termino"] ):
                #    eg[0]["data_termino"] = d
                #eg[0]["tempo_medio"] = (eg[0]["data_termino"] - eg[0]["data_inicio"])\
                #/ eg[0]["peso"]
                
                if not (len(eg) > 0):
                    g.add_edges([(ent , row['entidades'][index+1])])
                    #eg = g.es.select(lambda edge: edge.source_vertex["name"]  == ent and \
                    #        edge.target_vertex["name"] == row['entidades'][index+1] ) 
                    #eg[0]["data_inicio"] =  d
                    #eg[0]["data_termino"] =  d
                    #eg[0]["peso"] =  1
                    #eg[0]["tempo_medio"]=0.0
                    #contador_arestas = contador_arestas + 1        
        #print("vertices: " + str(contador_vertices) + " arestas: " + str(contador_arestas), end='\r' )
    #print("vertices: " + str(contador_vertices) + " arestas: " + str(contador_arestas) )
    print(g.summary())
    main.show_current_time()
    for vx in g.vs:
        print(vx.attributes())        
    for es in g.es:
        print(len(g.es), es.source_vertex["name"],"---->", es.target_vertex["name"],es.attributes())        
    with open("grafo"+str(ano)+".pkl", 'wb') as pickle_file:
        pickle.dump(g, pickle_file)
    print("------------------------------------")                 
print("Término da criação dos grafos anuais.")    
main.show_current_time()
